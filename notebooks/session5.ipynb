# %% [markdown]
# # Session 5: Testing & CI

# %% [markdown]
# ## Outline
#
# - [Git](https://www.atlassian.com/git/tutorials/comparing-workflows)
# - Testing
#   - [unittest](https://docs.python.org/3/library/unittest.html)
#   - [pytest](https://docs.pytest.org/en/stable/)
#   - [coverage](https://coverage.readthedocs.io/en/coverage-5.5/)
# - [Mocking](https://docs.python.org/3/library/unittest.mock.html)
# - [CI/CD with GitHub Actions](https://docs.github.com/en/actions)

# %% [markdown]
# ## Git
#
# Git: The industry standard. We explored how Git is used in companies, especially the branching model:
#
# - main/master: Production-ready code
# - develop: Integration branch for features
# - feature/: Isolated branches for new work
# - release/ and hotfix/: For deployment and urgent fixes

# %% [markdown]
# ## Unittest
